# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # MOGONET: Multi-omics Integration via Graph Convolutional Networks for Biomedical Data Classification
#
# https://github.com/txWang/MOGONET

# %%
#!git clone https://github.com/txWang/MOGONET.git
# !git clone https://github.com/napoler/MOGONET.git
# Out:
# Cloning into 'MOGONET'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 130 (delta 12), reused 115 (delta 6), pack-reused 0
# Receiving objects: 100% (130/130), 57.45 MiB | 22.21 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# %cd ./MOGONET
# !mkdir out
# Out:
# /kaggle/working/MOGONET

# %%
# !python main_mogonet.py
# Out:
# Pretrain GCNs...
#
# Training...
#
# Test: Epoch 0
# Test ACC: 0.481
# Test F1: 0.368
# Test AUC: 0.515
#
#
# Test: Epoch 50
# Test ACC: 0.604
# Test F1: 0.716
# Test AUC: 0.831
#
#
# Test: Epoch 100
# Test ACC: 0.726
# Test F1: 0.768
# Test AUC: 0.844
#
#
# Test: Epoch 150
# Test ACC: 0.821
# Test F1: 0.822
# Test AUC: 0.886
#
#
# Test: Epoch 200
# Test ACC: 0.840
# Test F1: 0.847
# Test AUC: 0.913
#
#
# Test: Epoch 250
# Test ACC: 0.821
# Test F1: 0.829
# Test AUC: 0.907
#
#
# Test: Epoch 300
# Test ACC: 0.830
# Test F1: 0.839
# Test AUC: 0.909
#
#
# Test: Epoch 350
# Test ACC: 0.821
# Test F1: 0.816
# Test AUC: 0.903
#
#
# Test: Epoch 400
# Test ACC: 0.830
# Test F1: 0.839
# Test AUC: 0.910
#
#
# Test: Epoch 450
# Test ACC: 0.802
# Test F1: 0.829
# Test AUC: 0.910
#
#
# Test: Epoch 500
# Test ACC: 0.830
# Test F1: 0.827
# Test AUC: 0.903
#
#
# Test: Epoch 550
# Test ACC: 0.849
# Test F1: 0.846
# Test AUC: 0.905
#
#
# Test: Epoch 600
# Test ACC: 0.858
# Test F1: 0.862
# Test AUC: 0.905
#
#
# Test: Epoch 650
# Test ACC: 0.830
# Test F1: 0.824
# Test AUC: 0.903
#
#
# Test: Epoch 700
# Test ACC: 0.821
# Test F1: 0.812
# Test AUC: 0.895
#
#
# Test: Epoch 750
# Test ACC: 0.840
# Test F1: 0.844
# Test AUC: 0.902
#
#
# Test: Epoch 800
# Test ACC: 0.811
# Test F1: 0.811
# Test AUC: 0.902
#
#
# Test: Epoch 850
# Test ACC: 0.821
# Test F1: 0.822
# Test AUC: 0.891
#
#
# Test: Epoch 900
# Test ACC: 0.849
# Test F1: 0.843
# Test AUC: 0.907
#
#
# Test: Epoch 950
# Test ACC: 0.830
# Test F1: 0.847
# Test AUC: 0.904
#
#
# Test: Epoch 1000
# Test ACC: 0.830
# Test F1: 0.827
# Test AUC: 0.894
#
#
# Test: Epoch 1050
# Test ACC: 0.811
# Test F1: 0.792
# Test AUC: 0.888
#
#
# Test: Epoch 1100
# Test ACC: 0.811
# Test F1: 0.787
# Test AUC: 0.899
#
#
# Test: Epoch 1150
# Test ACC: 0.830
# Test F1: 0.830
# Test AUC: 0.905
#
#
# Test: Epoch 1200
# Test ACC: 0.811
# Test F1: 0.804
# Test AUC: 0.886
#
#
# Test: Epoch 1250
# Test ACC: 0.811
# Test F1: 0.800
# Test AUC: 0.889
#
#
# Test: Epoch 1300
# Test ACC: 0.792
# Test F1: 0.792
# Test AUC: 0.888
#
#
# Test: Epoch 1350
# Test ACC: 0.821
# Test F1: 0.816
# Test AUC: 0.896
#
#
# Test: Epoch 1400
# Test ACC: 0.811
# Test F1: 0.815
# Test AUC: 0.899
#
#
# Test: Epoch 1450
# Test ACC: 0.821
# Test F1: 0.808
# Test AUC: 0.889
#
#
# Test: Epoch 1500
# Test ACC: 0.821
# Test F1: 0.808
# Test AUC: 0.898
#
#
# Test: Epoch 1550
# Test ACC: 0.792
# Test F1: 0.766
# Test AUC: 0.882
#
#
# Test: Epoch 1600
# Test ACC: 0.821
# Test F1: 0.819
# Test AUC: 0.894
#
#
# Test: Epoch 1650
# Test ACC: 0.811
# Test F1: 0.811
# Test AUC: 0.877
#
#
# Test: Epoch 1700
# Test ACC: 0.830
# Test F1: 0.842
# Test AUC: 0.902
#
#
# Test: Epoch 1750
# Test ACC: 0.792
# Test F1: 0.800
# Test AUC: 0.890
#
#
# Test: Epoch 1800
# Test ACC: 0.783
# Test F1: 0.785
# Test AUC: 0.884
#
#
# Test: Epoch 1850
# Test ACC: 0.802
# Test F1: 0.807
# Test AUC: 0.886
#
#
# Test: Epoch 1900
# Test ACC: 0.830
# Test F1: 0.827
# Test AUC: 0.896
#
#
# Test: Epoch 1950
# Test ACC: 0.764
# Test F1: 0.797
# Test AUC: 0.889
#
#
# Test: Epoch 2000
# Test ACC: 0.811
# Test F1: 0.811
# Test AUC: 0.890
#
#
# Test: Epoch 2050
# Test ACC: 0.840
# Test F1: 0.844
# Test AUC: 0.912
#
#
# Test: Epoch 2100
# Test ACC: 0.821
# Test F1: 0.812
# Test AUC: 0.892
#
#
# Test: Epoch 2150
# Test ACC: 0.858
# Test F1: 0.857
# Test AUC: 0.887
#
#
# Test: Epoch 2200
# Test ACC: 0.830
# Test F1: 0.820
# Test AUC: 0.891
#
#
# Test: Epoch 2250
# Test ACC: 0.792
# Test F1: 0.814
# Test AUC: 0.902
#
#
# Test: Epoch 2300
# Test ACC: 0.783
# Test F1: 0.800
# Test AUC: 0.893
#
#
# Test: Epoch 2350
# Test ACC: 0.840
# Test F1: 0.838
# Test AUC: 0.887
#
#
# Test: Epoch 2400
# Test ACC: 0.774
# Test F1: 0.800
# Test AUC: 0.891
#
#
# Test: Epoch 2450
# Test ACC: 0.821
# Test F1: 0.812
# Test AUC: 0.881
#
#
# Test: Epoch 2500
# Test ACC: 0.821
# Test F1: 0.812
# Test AUC: 0.887
